# %%
from config.config import get_news_dir
from data.news import YahooNews


y = YahooNews("AAPL", get_news_dir())

y.get_news()
# Out:
# Content: {'id': 'ffd9cd30-d2e4-36fc-b010-5550db73493e', 'contentType': 'STORY', 'title': "Alphabet Stock Sell-Off: 4 Reasons Why You Shouldn't Panic About Google Search", 'description': '', 'summary': 'Alphabet shares came under pressure after an Apple exec said they saw search queries decline for the first time.  Shares of Alphabet (NASDAQ: GOOGL) (NASDAQ: GOOG) sank after Apple executive Eddy Cue said that searches on Safari declined for the first time ever in April.  Cue attributed the decline to people using more artificial intelligence (AI) chatbots and predicted that AI search engines will eventually replace traditional search.', 'pubDate': '2025-05-10T20:45:00Z', 'displayTime': '2025-05-10T20:45:00Z', 'isHosted': True, 'bypassModal': False, 'previewUrl': None, 'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/motleyfool.com/8b19c7c97a0cf753d380e8e871b83223', 'originalWidth': 1400, 'originalHeight': 1051, 'caption': 'Artist rendering of search on laptop.', 'resolutions':
# ...

# %%
from utils.llm import  Ollama

o = Ollama()

r = o.generate("qwen3:8b", "What is the capital of France?")

r
