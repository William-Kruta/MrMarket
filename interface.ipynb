# %%
from data.statements import FinancialStatements
from config.config import  get_daily_candles_dir, get_statements_dir

f = FinancialStatements("AAPL", get_statements_dir(), get_daily_candles_dir())

data = f.get_statements()
# Out:
# Candles:                  Close        High         Low        Open    Volume
# Date
# 2021-01-13   96.364998  103.000000   90.010002   90.900002  25159000
# 2021-01-14  114.940002  137.979996  101.000000  103.500000  20858700
# 2021-01-15  117.000000  127.239998  107.000000  123.054001   8310700
# 2021-01-19  110.989998  117.675003  108.000000  117.000000   3304900
# 2021-01-20  106.209999  112.000000  103.250000  110.000000   5091400
# ...                ...         ...         ...         ...       ...
# 2025-05-05   52.090000   53.259998   51.380001   51.389999   4896100
# 2025-05-06   51.000000   51.810001   50.400002   51.049999   5236300
# 2025-05-07   51.540001   52.200001   50.028000   50.735001   5387300
# 2025-05-08   54.259998   55.759998   53.299999   53.575001  17051800
# 2025-05-09   46.410000   51.200001   45.540001   50.145000  31879645
#
# [1086 rows x 5 columns]
# High: nan
# High: 146.89999389648438
# High: 176.64999389648438
# High: 40.970001220703125
# ...

# %%
d = data["income_statement"].index.to_list()

for i in d[:]:
    print(i)
# Out:
# Tax Effect Of Unusual Items
# Tax Rate For Calcs
# Normalized EBITDA
# Total Unusual Items
# Total Unusual Items Excluding Goodwill
# Net Income From Continuing Operation Net Minority Interest
# Reconciled Depreciation
# Reconciled Cost Of Revenue
# EBITDA
# EBIT
# Net Interest Income
# Interest Expense
# Interest Income
# Normalized Income
# Net Income From Continuing And Discontinued Operation
# Total Expenses
# Total Operating Income As Reported
# Diluted Average Shares
# Basic Average Shares
# Diluted EPS
# Basic EPS
# Diluted NI Availto Com Stockholders
# Net Income Common Stockholders
# Otherunder Preferred Stock Dividend
# Net Income
# Net Income Including Noncontrolling Interests
# Net Income Continuous Operations
# Tax Provision
# Pretax Income
# Other Income Expense
# Other Non Operating Income Expenses
# Special Income Charges
# Gain On Sale Of Ppe
# Restructuring And Mergern Acquisition
# Net Non Operating Interest Income Expense
# Total Other Finance Cost
# ...
